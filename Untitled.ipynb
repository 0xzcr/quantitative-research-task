# %% [markdown]
# # TASK 2: - write a script that traders can use to price the contract
#
# **important pointers from the task description:**
# - any trade agreement is as valuable as the price you can sell minus the price at which you are able to buy. Any cost incurred as part of executing this agreement is also deducted from the overall value.
# - ***A gas storage contract is worth the price difference between buying and selling, minus all operational costs.***
# - from the given example, we can deduce the contract to look like :-
#
#   $$Contract Value=(Sell Price−Buy Price)×Quantity−All Costs$$

# %%
import pandas as pd

# %%
#read data
df = pd.read_csv('final_gas_prices.csv')
df
# Out:
#          Dates  FinalPrice
# 0   2020-10-31   10.100000
# 1   2020-11-30   10.300000
# 2   2020-12-31   11.000000
# 3   2021-01-31   10.900000
# 4   2021-02-28   10.900000
# 5   2021-03-31   10.900000
# 6   2021-04-30   10.400000
# 7   2021-05-31    9.840000
# 8   2021-06-30   10.000000
# 9   2021-07-31   10.100000
# 10  2021-08-31   10.300000
# 11  2021-09-30   10.200000
# 12  2021-10-31   10.100000
# 13  2021-11-30   11.200000
# 14  2021-12-31   11.400000
# 15  2022-01-31   11.500000
# 16  2022-02-28   11.800000
# 17  2022-03-31   11.500000
# 18  2022-04-30   10.700000
# 19  2022-05-31   10.700000
# 20  2022-06-30   10.400000
# 21  2022-07-31   10.500000
# 22  2022-08-31   10.400000
# 23  2022-09-30   10.800000
# 24  2022-10-31   11.000000
# 25  2022-11-30   11.600000
# 26  2022-12-31   11.600000
# 27  2023-01-31   12.100000
# 28  2023-02-28   11.700000
# 29  2023-03-31   12.000000
# 30  2023-04-30   11.500000
# 31  2023-05-31   11.200000
# 32  2023-06-30   10.900000
# ...
